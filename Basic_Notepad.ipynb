# %% [markdown]
# <a href="https://colab.research.google.com/github/OldSinner/MachineLearningCourse/blob/Begining/Basic_Notepad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# This notepad was created to get used to use Jupyter, at the same time, it is the beginning of the ML learning process
#
# ## Course that i used in this notebook:
# [Machine Learning for Everybody – Full Course](https://www.youtube.com/watch?v=i_LwzRVP7bg)

# %% [markdown]
# ## Dataset Source:
# ### Original Owner:
#
# R. K. Bock
# Major Atmospheric Gamma Imaging Cherenkov Telescope project (MAGIC)
# http://wwwmagic.mppmu.mpg.de
# rkb '@' mail.cern.ch
#
# ### Donor:
#
# P. Savicky
# Institute of Computer Science, AS of CR
# Czech Republic
# savicky '@' cs.cas.cz

# %% [markdown]
# ## Preparation of the environment
#
# Preparing the environment by loading libraries

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Section 1: Supervised Learning

# %% [markdown]
# ### Data Prepare
# The beginning of the course. This is where we load the data and perform basic processing. <br>
# Data with class **"g"** (for gamma), was labeled as **1** <br>
# Data with class **"h"** (for hadron), was labeled as **0** <br>
# <br>

# %%
cols = ["fLength","fWidth","fSize","fConc","fConc1","fAsym","fM3Long","fM3Trans","fAlpha","fDist","class"]
data = pd.read_csv("magic04.data", names=cols)
data["class"] = (data["class"] == "g").astype(int)
data["class"].unique()
# Out:
# array([1, 0])

# %% [markdown]
# In this chapter, I will use "Supervised Learing" - This is a way of learning a model, where the inputs have an appropriate label that informs what classification should be correct.

# %% [markdown]
# ## Theory
# ---

# %% [markdown]
# ### Model
#   In machine learning, we can define 3 elements when it comes to the system itself.
# We have:
# - Inputs
# - model
# - Output (Prediction)
# ---
# ![graph (1).png](data:image/png;base64,...)
